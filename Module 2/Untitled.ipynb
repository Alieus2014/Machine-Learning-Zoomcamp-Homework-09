# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df= pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df[["engine_displacement","horsepower","vehicle_weight","model_year","fuel_efficiency_mpg"]].head()
# Out:
#    engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                  170       159.0     3413.433759        2003
# 1                  130        97.0     3149.664934        2007
# 2                  170        78.0     3079.038997        2018
# 3                  220         NaN     2542.392402        2009
# 4                  210       140.0     3460.870990        2009
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
s = df['fuel_efficiency_mpg'].dropna()
sk = s.skew()
print(f"Skew = {sk:.3f}")
print("Conclusion:",
      "long right tail" if sk > 1
      else "long left tail" if sk < -1
      else "no pronounced long tail")
# Out:
# Skew = -0.012
# Conclusion: no pronounced long tail

# %% [markdown]
# Question 1
# There's one column with missing values. What is it?

# %%
cols = ["engine_displacement","horsepower","vehicle_weight","model_year","fuel_efficiency_mpg"]
df[cols].isna().sum().pipe(lambda s: s[s>0]).to_string(dtype=False)
# Out:
# 'horsepower    708'

# %% [markdown]
# Question 2
# What's the median (50% percentile) for variable 'horsepower'?

# %%
df['horsepower'].median()
print(df['horsepower'].median().item())
# Out:
# 149.0

# %%
SEED = 42
df_shuffled = df.sample(frac=1, random_state=SEED).reset_index(drop=True)

# %%
SEED=42
df_ = df.sample(frac=1, random_state=SEED).reset_index(drop=True)
n=len(df_)
n_train=int(0.6*n); n_val=int(0.2*n)
df_train = df_.iloc[:n_train].copy()
df_val   = df_.iloc[n_train:n_train+n_val].copy()
df_test  = df_.iloc[n_train+n_val:].copy()
